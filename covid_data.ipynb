# %% [markdown]
# # Spring Break During Covid
#
# ## Members
#
# -Robyn Leslie
# -Jennifer Hooker
# -Traci Ellis
# -Brittany Butchkoski
#
# # Introduction
#
# Imagine you are a college student planning on taking a trip out of state to go on vacation for spring break but we are still in the middle of a pandemic. To be able to travel and actually enjoy your vacation you must avoid all heavy populated areas with Covid. The data we have collected from 2020 to early 2023 will help us predict just how to do so by mapping out the covid hotspots in the US, and three popular states to visit while on spring break, we will aslo have a break down of those three states by county so you know which areas to steer clear of.
#
# The three states chosen are as listed:
#
# -Florida
#
# -New York
#
# -Colorado
#
# For each of these states we have chosen five popular attractions to visit. And have shown whether or not it is safe to visit them based on what was collected from The New York Times Coronavirus data.
#
# These observations will be based on data collected by The New York Times from 01 January 2020- 23 March 2023. The New York Times released a series of data files with cumulative counts of coronavirus cases in the United States, at the state and county level, over time. Although since the first reported case was not until January 21st 2020, The New York Times has tracked the cases of the virus in real time as they were identified after testing. Unfortunately due to a wide spread shortage in testing data was limited which may affect the overall picture presented of the outbreak.
#
# The data collected may be flawed in the sense that if a person was diagnosed with covid in FL for example but died in another state the state they died in would count the death for their state and FL would also document the death in their records as well. Another issue would be the delay of information, once the information was avaliable it was added to the data set.
#
# "Probable" and "Confirmed cases and Deaths"
# Confirmed cases and Deaths can be either be confirmed as "confirmed" or "probable". The number of cases represents the cases that have recovered or died. And the total cases and deaths include both. Some governments continued to report only confirmed cases, while others are reporting both confirmed and probable numbers. Some reporting the two types of numbers combined without providing a way to separate the confirmed from the probable. This may alter the results of the data as well.
#
# The Geographic Exceptions section below has more details on specific areas. The methodology of individual states changes frequently.
#
# #### New York
#
# All cases for the five boroughs of New York City (New York, Kings, Queens, Bronx and Richmond counties) are assigned to a single area called New York City. The number of deaths in New York City also includes probable deaths reported by the New York City health department. Deaths are reported by county of residence, except for certain periods described below.
#
# The New York Times has changed the way we have counted deaths in New York State a few times in response to changes in how the state and New York City report their data.
#
# #### Confirmed cases:
#
# Are counts of individuals whose coronavirus infections were confirmed by a laboratory test and reported by a federal, state, territorial or local government agency. Only tests that detect viral RNA in a sample are considered confirmatory. These are often called molecular or RT-PCR tests.
#
# #### Probable cases:
#
# Count individuals who did not have a confirmed test but were evaluated by public health officials using criteria developed by states and the federal government and reported by a health department.
#
# Public health officials consider laboratory, epidemiological, clinical and vital records evidence. Tests that detect antigens or antibodies are considered evidence towards a “probable” case, but are not sufficient on their own, according to the Council of State and Territorial Epidemiologists.
#
# #### Confirmed Deaths:
#
# Confirmed deaths are individuals who have died and meet the definition for a confirmed Covid-19 case. Some states reconcile these records with death certificates to remove deaths from their count where Covid-19 is not listed as the cause of death. We follow health departments in removing non-Covid-19 deaths among confirmed cases when we have information to unambiguously know the deaths were not due to Covid-19, i.e. in cases of homicide, suicide, car crash or drug overdose.
#
# #### Probable Deaths:
#
# Probable deaths are deaths where Covid-19 is listed on the death certificate as the cause of death or a significant contributing condition, but where there has been no positive confirmatory laboratory test.
#
# Deaths among probable cases tracked by a state or local health department where a death certificate has not yet been filed may also be counted as a probable death.
#
# #### FIPS
#
# FIPS stands for Federal Information Proccessing Standards. It is a standard for adoption and use by United States Federal departments and agencies that has been developed within the Information Technology Laboratory and published by the National Institute of Standards and Technology (NIST), a part of the U.S. Department of Commerce. FIPS codes are numbers which uniquely identify geographic areas. The number of digits in FIPS codes vary depending on the level of geography. State-level FIPS codes have two digits, county-level FIPS codes have five digits of which the first two are the FIPS code of the state to which the county belongs.
#
# Here is a link that shows the US FIPS codes:
#
# https://transition.fcc.gov/oet/info/maps/census/fips/fips.txt#:~:text=FIPS%20codes%20are%20numbers%20which,to%20which%20the%20county%20belongs.
#
#
# # Ethical Considerations:
#
# For this project we decided to use data collected by The New York Times. In order to do so we had to inform The New York Times that we plan on using their data from their github for our project. This follows ethical standards because we asked for consent for the use of their data that they collected. The New  York Times was also transparent about the discrepancies in the data from how it was documented from other sources, as mentioned above. The data we decided to use for the project may not be exact but it will still give us a good overall picture of the covid statics for the US, states chosen, and their counties. The data used for this project also follows confidentiality in the sense that patients names were not mentioned, only the necessary data was used for the project.
#
#
#
#
# # References
#
#  "The New York Times. (2021). Coronavirus (Covid-19) Data in the United States. Retrieved [09 January 2024], from https://github.com/nytimes/covid-19-data."
#
#  https://transition.fcc.gov/oet/info/maps/census/fips/fips.txt#:~:text=FIPS%20codes%20are%20numbers%20which,to%20which%20the%20county%20belongs.
#
#
#
# Here is a link that shows the US FIPS codes:
# https://transition.fcc.gov/oet/info/maps/census/fips/fips.txt#:~:text=FIPS%20codes%20are%20numbers%20which,to%20which%20the%20county%20belongs.

# %%
#import dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json as js
from datetime import datetime
from datetime import date
# Out:
# c:\Users\lesli\anaconda3\envs\dev\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Read the csv files into dataframes
counties20_df = pd.read_csv("data/us-counties-2020.csv")
counties21_df = pd.read_csv("data/us-counties-2021.csv")
counties22_df = pd.read_csv("data/us-counties-2022.csv")
counties23_df = pd.read_csv("data/us-counties-2023.csv")
states_df = pd.read_csv("data/us-states.csv")
us_df = pd.read_csv("data/us.csv")

# %%
counties20_df.set_index(['date','county','state','fips','cases','deaths'])
counties20_df
# Out:
#               date      county       state     fips  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...            ...         ...         ...      ...    ...     ...
# 884732  2020-12-31  Sweetwater     Wyoming  56037.0   2966    16.0
# 884733  2020-12-31       Teton     Wyoming  56039.0   2138     4.0
# 884734  2020-12-31       Uinta     Wyoming  56041.0   1558     7.0
# 884735  2020-12-31    Washakie     Wyoming  56043.0    780    19.0
# 884736  2020-12-31      Weston     Wyoming  56045.0    476     2.0
#
# [884737 rows x 6 columns]

# %%
counties21_df.set_index(['date','county','state','fips','cases','deaths'])
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
counties22_df.set_index(['date','county','state','fips','cases','deaths'])
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
counties23_df.set_index(['date','county','state','fips','cases','deaths'])
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
states_df
# Out:
#              date          state  fips    cases  deaths
# 0      2020-01-21     Washington    53        1       0
# 1      2020-01-22     Washington    53        1       0
# 2      2020-01-23     Washington    53        1       0
# 3      2020-01-24       Illinois    17        1       0
# 4      2020-01-24     Washington    53        1       0
# ...           ...            ...   ...      ...     ...
# 61937  2023-03-23       Virginia    51  2298300   23782
# 61938  2023-03-23     Washington    53  1940704   15905
# 61939  2023-03-23  West Virginia    54   645710    8132
# 61940  2023-03-23      Wisconsin    55  2014524   16485
# 61941  2023-03-23        Wyoming    56   185800    2014
#
# [61942 rows x 5 columns]

# %%
us_df
# Out:
#             date      cases   deaths
# 0     2020-01-21          1        0
# 1     2020-01-22          1        0
# 2     2020-01-23          1        0
# 3     2020-01-24          2        0
# 4     2020-01-25          3        0
# ...          ...        ...      ...
# 1153  2023-03-19  103784916  1133826
# 1154  2023-03-20  103794703  1133964
# 1155  2023-03-21  103813076  1134177
# 1156  2023-03-22  103864888  1134913
# 1157  2023-03-23  103910034  1135343
#
# [1158 rows x 3 columns]

# %%
#Pull columns needed (date, county,state,cases,and deaths) from dataframes 
# Merge counties dataframes
counties20to21_df = pd.merge(counties20_df, counties21_df, on=['date','county','state','fips','cases','deaths'], how='outer')
#print(counties20to21_df)
counties22to23_df = pd.merge(counties22_df, counties23_df, on=['date','county','state','fips','cases','deaths'], how='outer')
#counties22to23_df
counties20to23_df = pd.merge(counties20to21_df, counties22to23_df,  on=['date','county','state','fips','cases','deaths'], how='outer')
#counties20to23_df


print(counties20to23_df)
# Out:
#                date     county         state     fips  cases  deaths
# 0        2020-01-21  Snohomish    Washington  53061.0      1     0.0
# 1        2020-01-22  Snohomish    Washington  53061.0      1     0.0
# 2        2020-01-23  Snohomish    Washington  53061.0      1     0.0
# 3        2020-01-24       Cook      Illinois  17031.0      1     0.0
# 4        2020-01-24  Snohomish    Washington  53061.0      1     0.0
# ...             ...        ...           ...      ...    ...     ...
# 3525156  2023-03-23       Yuma       Arizona   4027.0  71397  1259.0
# 3525157  2023-03-23       Yuma      Colorado   8125.0   2349    27.0
# 3525158  2023-03-23     Zapata         Texas  48505.0   4411    57.0
# 3525159  2023-03-23     Zavala         Texas  48507.0   4386    70.0
# 3525160  2023-03-23    Ziebach  South Dakota  46137.0    720    13.0
#
# [3525161 rows x 6 columns]

# %%
#sort date for March ( typical months for Spring Break) for the counties
# df['Date'] = pd.to_datetime(df['Date']) -- if column is not datetime yet
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')

counties20to23_df['date'] = pd.to_datetime(counties20to23_df['date'])
counties20to23_mar_df= counties20to23_df[counties20to23_df['date'].dt.month == 3]

#save df as a csv file
counties20to23_mar_df.to_csv('data/counties20to23_mar.csv')

#show df
counties20to23_mar_df
# Out:
#               date   county         state     fips  cases  deaths
# 398     2020-03-01  Alameda    California   6001.0      1     0.0
# 399     2020-03-01    Bexar         Texas  48029.0     11     0.0
# 400     2020-03-01     Cook      Illinois  17031.0      3     0.0
# 401     2020-03-01     Dane     Wisconsin  55025.0      1     0.0
# 402     2020-03-01  Douglas      Nebraska  31055.0     13     0.0
# ...            ...      ...           ...      ...    ...     ...
# 3525156 2023-03-23     Yuma       Arizona   4027.0  71397  1259.0
# 3525157 2023-03-23     Yuma      Colorado   8125.0   2349    27.0
# 3525158 2023-03-23   Zapata         Texas  48505.0   4411    57.0
# 3525159 2023-03-23   Zavala         Texas  48507.0   4386    70.0
# 3525160 2023-03-23  Ziebach  South Dakota  46137.0    720    13.0
#
# [299855 rows x 6 columns]

# %%
#sort date for March ( typical months for Spring Break) for the states
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
#datetime.datetime(2014, 7, 28, 18, 54, 55, 99000)
states_df['date'] = pd.to_datetime(states_df['date'])
#states_df['month'] = states_df['date'].dt.month
states_mar_df= states_df[states_df['date'].dt.month == 3]
#save df as a csv file
states_mar_df.to_csv('data/states_mar.csv')
#show df
states_mar_df
# Out:
#             date          state  fips    cases  deaths
# 240   2020-03-01        Arizona     4        1       0
# 241   2020-03-01     California     6       33       0
# 242   2020-03-01        Florida    12        2       0
# 243   2020-03-01       Illinois    17        3       0
# 244   2020-03-01  Massachusetts    25        1       0
# ...          ...            ...   ...      ...     ...
# 61937 2023-03-23       Virginia    51  2298300   23782
# 61938 2023-03-23     Washington    53  1940704   15905
# 61939 2023-03-23  West Virginia    54   645710    8132
# 61940 2023-03-23      Wisconsin    55  2014524   16485
# 61941 2023-03-23        Wyoming    56   185800    2014
#
# [6098 rows x 5 columns]

# %%
#sort date for March ( typical months for Spring Break) for the us
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
#datetime.datetime(2014, 7, 28, 18, 54, 55, 99000)
us_df['date'] = pd.to_datetime(us_df['date'])
#us_df['month'] = us_df['date'].dt.month
us_mar_df= us_df[us_df['date'].dt.month == 3]
#save df as a csv file
us_mar_df.to_csv('data/us_mar.csv')
#show df
us_mar_df
# Out:
#            date      cases   deaths
# 40   2020-03-01         88        3
# 41   2020-03-02        104        6
# 42   2020-03-03        125       10
# 43   2020-03-04        161       12
# 44   2020-03-05        228       12
# ...         ...        ...      ...
# 1153 2023-03-19  103784916  1133826
# 1154 2023-03-20  103794703  1133964
# 1155 2023-03-21  103813076  1134177
# 1156 2023-03-22  103864888  1134913
# 1157 2023-03-23  103910034  1135343
#
# [116 rows x 3 columns]

# %%
#Chosen states Covid Cases in March 2020.
states_mar20_df= states_df[states_df['date'].dt.year == 2020]

# Applying filter function.  

options = ['Colorado', 'New York','Florida'] 
   
# Selecting rows based on condition 
states_mar20_df = states_mar20_df.loc[states_mar20_df['state'].isin(options)] 

states_mar20_df
# Out:
#             date     state  fips    cases  deaths
# 242   2020-03-01   Florida    12        2       0
# 246   2020-03-01  New York    36        1       0
# 255   2020-03-02   Florida    12        2       0
# 261   2020-03-02  New York    36        1       0
# 270   2020-03-03   Florida    12        3       0
# ...          ...       ...   ...      ...     ...
# 16633 2020-12-30   Florida    12  1306115   21545
# 16657 2020-12-30  New York    36   963647   37412
# 16684 2020-12-31  Colorado     8   335579    4879
# 16688 2020-12-31   Florida    12  1323307   21672
# 16712 2020-12-31  New York    36   979040   37557
#
# [914 rows x 5 columns]

# %%
#Identify the state with the highest number of covid cases

highest_cases = states_mar20_df['cases'].max()
state_with_highest_cases = states_mar20_df.loc[states_mar20_df['cases'].idxmax(), 'state']
print("The highest number of cases is:", highest_cases)
print("The state with the highest number of cases is:", state_with_highest_cases)
# Out:
# The highest number of cases is: 1323307
# The state with the highest number of cases is: Florida

# %%
#Identify the state with the lowest number of covid cases
lowest_cases = states_mar20_df['cases'].min()
state_with_lowest_cases = states_mar20_df.loc[states_mar20_df['cases'].idxmin(), 'state']
print("The lowest number of cases is:", lowest_cases)
print("The state with the least amount of cases is:", state_with_lowest_cases)
# Out:
# The lowest number of cases is: 1
# The state with the least amount of cases is: New York

# %%
# Define the colors for each state
color_palette = {"Colorado": "blue", "New York": "red", "Florida": "green"}

# Create the bar plot
covidcasesstates_mar20 = sns.barplot(x="state", y="cases", hue="state", data=states_mar20_df, dodge=False, palette=color_palette)

# Set the title and axis labels
covidcasesstates_mar20.set_title('March 2020 Covid Cases')
covidcasesstates_mar20.set_xlabel('States', fontdict={'size': 15})
covidcasesstates_mar20.set_ylabel('Number of Cases (in millions)', fontdict={'size': 15})

# Set the y-axis limits
plt.ylim([0, 8000000])

# Save the image
plt.savefig('images/March_2020_cases.png', dpi=100)

# Show the plot
plt.show()

# %%
#Chosen states Covid Cases in March 2021.
states_mar21_df= states_df[states_df['date'].dt.year == 2021]

# Applying filter function.  

options = ['Colorado', 'New York','Florida'] 
   
# Selecting rows based on condition 
states_mar21_df = states_mar21_df.loc[states_mar21_df['state'].isin(options)] 
states_mar21_df
# Out:
#             date     state  fips    cases  deaths
# 16739 2021-01-01  Colorado     8   338357    4936
# 16743 2021-01-01   Florida    12  1323307   21672
# 16767 2021-01-01  New York    36   996073   37733
# 16794 2021-01-02  Colorado     8   340454    4976
# 16798 2021-01-02   Florida    12  1354825   21889
# ...          ...       ...   ...      ...     ...
# 36808 2021-12-30   Florida    12  4090000   62480
# 36832 2021-12-30  New York    36  3395166   58917
# 36860 2021-12-31  Colorado     8   933257   10480
# 36864 2021-12-31   Florida    12  4166392   62504
# 36888 2021-12-31  New York    36  3473970   58993
#
# [1095 rows x 5 columns]

# %%
#Identify the state with the highest number of covid cases
highest_cases = states_mar21_df['cases'].max()
state_with_highest_cases = states_mar21_df.loc[states_mar21_df['cases'].idxmax(), 'state']
print("The highest number of cases is:", highest_cases)
print("The state with the highest number of cases is:", state_with_highest_cases)
# Out:
# The highest number of cases is: 4166392
# The state with the highest number of cases is: Florida

# %%
#Identify the state with the lowest number of covid cases
lowest_cases = states_mar21_df['cases'].min()
state_with_lowest_cases = states_mar21_df.loc[states_mar21_df['cases'].idxmin(), 'state']
print("The lowest number of cases is:", lowest_cases)
print("The state with the least amount of cases is:", state_with_lowest_cases)
# Out:
# The lowest number of cases is: 338357
# The state with the least amount of cases is: Colorado

# %%
# Define the colors for each state
color_palette = {"Colorado": "blue", "New York": "red", "Florida": "green"}

# Create the bar plot
covidcasesstates_mar21 = sns.barplot(x="state", y="cases", hue="state", data=states_mar21_df, dodge=False, palette=color_palette)

# Set the title and axis labels
covidcasesstates_mar21.set_title('March 2021 Covid Cases')
covidcasesstates_mar21.set_xlabel('States', fontdict={'size': 15})
covidcasesstates_mar21.set_ylabel('Number of Cases (in millions)', fontdict={'size': 15})

# Set the y-axis limits
plt.ylim([0, 8000000])

# Save the image
plt.savefig('images/March_2021_cases.png', dpi=100)

# Show the plot
plt.show()

# %%
#Chosen states Covid Cases in March 2022.
states_mar22_df= states_df[states_df['date'].dt.year == 2022]

# Applying filter function.  

options = ['Colorado', 'New York','Florida'] 
   
# Selecting rows based on condition 
states_mar22_df = states_mar22_df.loc[states_mar22_df['state'].isin(options)] 
states_mar22_df
# Out:
#             date     state  fips    cases  deaths
# 36916 2022-01-01  Colorado     8   933257   10480
# 36920 2022-01-01   Florida    12  4166392   62504
# 36944 2022-01-01  New York    36  3555047   59072
# 36972 2022-01-02  Colorado     8   936422   10485
# 36976 2022-01-02   Florida    12  4166392   62504
# ...          ...       ...   ...      ...     ...
# 57248 2022-12-30   Florida    12  7269428   83911
# 57272 2022-12-30  New York    36  6560495   77722
# 57300 2022-12-31  Colorado     8  1734673   13899
# 57304 2022-12-31   Florida    12  7269428   83911
# 57328 2022-12-31  New York    36  6563605   77722
#
# [1095 rows x 5 columns]

# %%
#Identify the state with the highest number of covid cases
highest_cases = states_mar22_df['cases'].max()
state_with_highest_cases = states_mar22_df.loc[states_mar22_df['cases'].idxmax(), 'state']
print("The highest number of cases is:", highest_cases)
print("The state with the highest number of cases is:", state_with_highest_cases)
# Out:
# The highest number of cases is: 7269428
# The state with the highest number of cases is: Florida

# %%
#Identify the state with the lowest number of covid cases
lowest_cases = states_mar22_df['cases'].min()
state_with_lowest_cases = states_mar22_df.loc[states_mar22_df['cases'].idxmin(), 'state']
print("The lowest number of cases is:", lowest_cases)
print("The state with the least amount of cases is:", state_with_lowest_cases)
# Out:
# The lowest number of cases is: 933257
# The state with the least amount of cases is: Colorado

# %%
# Define the colors for each state
color_palette = {"Colorado": "blue", "New York": "red", "Florida": "green"}

# Create the bar plot
covidcasesstates_mar22 = sns.barplot(x="state", y="cases", hue="state", data=states_mar22_df, dodge=False, palette=color_palette)

# Set the title and axis labels
covidcasesstates_mar22.set_title('March 2022 Covid Cases')
covidcasesstates_mar22.set_xlabel('States', fontdict={'size': 15})
covidcasesstates_mar22.set_ylabel('Number of Cases (in millions)', fontdict={'size': 15})

# Set the y-axis limits
plt.ylim([0, 8000000])

# Save the image
plt.savefig('images/March_2022_cases.png', dpi=100)

# Show the plot
plt.show()

# %%
#Chosen states Covid Cases in March 2023.
states_mar23_df= states_df[states_df['date'].dt.year == 2023]

# Applying filter function.  

options = ['Colorado', 'New York','Florida'] 
   
# Selecting rows based on condition 
states_mar23_df = states_mar23_df.loc[states_mar23_df['state'].isin(options)] 
states_mar23_df
# Out:
#             date     state  fips    cases  deaths
# 57356 2023-01-01  Colorado     8  1734673   13899
# 57360 2023-01-01   Florida    12  7269428   83911
# 57384 2023-01-01  New York    36  6566031   77722
# 57412 2023-01-02  Colorado     8  1736048   13899
# 57416 2023-01-02   Florida    12  7269428   83911
# ...          ...       ...   ...      ...     ...
# 61840 2023-03-22   Florida    12  7542869   87141
# 61864 2023-03-22  New York    36  6803974   80138
# 61892 2023-03-23  Colorado     8  1771010   14245
# 61896 2023-03-23   Florida    12  7542869   87141
# 61920 2023-03-23  New York    36  6805271   80109
#
# [246 rows x 5 columns]

# %%
#Identify the state with the highest number of covid cases
highest_cases = states_mar23_df['cases'].max()
state_with_highest_cases = states_mar23_df.loc[states_mar23_df['cases'].idxmax(), 'state']
print("The highest number of cases is:", highest_cases)
print("The state with the highest number of cases is:", state_with_highest_cases)
# Out:
# The highest number of cases is: 7542869
# The state with the highest number of cases is: Florida

# %%
#Identify the state with the lowest number of covid cases
lowest_cases = states_mar23_df['cases'].min()
state_with_lowest_cases = states_mar23_df.loc[states_mar23_df['cases'].idxmin(), 'state']
print("The lowest number of cases is:", lowest_cases)
print("The state with the least amount of cases is:", state_with_lowest_cases)
# Out:
# The lowest number of cases is: 1734673
# The state with the least amount of cases is: Colorado

# %%
# Define the colors for each state
color_palette = {"Colorado": "blue", "New York": "red", "Florida": "green"}

# Create the bar plot
covidcasesstates_mar23 = sns.barplot(x="state", y="cases", hue="state", data=states_mar23_df, dodge=False, palette=color_palette)

# Set the title and axis labels
covidcasesstates_mar23.set_title('March 2023 Covid Cases')
covidcasesstates_mar23.set_xlabel('States', fontdict={'size': 15})
covidcasesstates_mar23.set_ylabel('Number of Cases (in millions)', fontdict={'size': 15})

# Set the y-axis limits
plt.ylim([0, 8000000])

# Save the image
plt.savefig('images/March_2023_cases.png', dpi=100)

# Show the plot
plt.show()

# %%
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
#datetime.datetime(2014, 7, 28, 18, 54, 55, 99000)
#states_mar_df['date'] = pd.to_datetime(states_mar_df['date'])

states_mar20_df.loc[:, 'date'] = pd.to_datetime(states_mar20_df.loc[:, 'date'])

#counties20to23_df['month'] = counties20to23_df['date'].dt.month
states_mar20_df= states_mar_df[states_mar_df['date'].dt.year == 2020]

#save df as a csv file
states_mar20_df.to_csv('data/states_mar20.csv')
#show df
states_mar20_df
# Out:
#            date          state  fips  cases  deaths
# 240  2020-03-01        Arizona     4      1       0
# 241  2020-03-01     California     6     33       0
# 242  2020-03-01        Florida    12      2       0
# 243  2020-03-01       Illinois    17      3       0
# 244  2020-03-01  Massachusetts    25      1       0
# ...         ...            ...   ...    ...     ...
# 1604 2020-03-31       Virginia    51   1249      27
# 1605 2020-03-31     Washington    53   5293     226
# 1606 2020-03-31  West Virginia    54    162       1
# 1607 2020-03-31      Wisconsin    55   1351      25
# 1608 2020-03-31        Wyoming    56    121       0
#
# [1369 rows x 5 columns]

# %%
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
#datetime.datetime(2014, 7, 28, 18, 54, 55, 99000)
#states_mar_df['date'] = pd.to_datetime(states_mar_df['date'])

states_mar21_df.loc[:, 'date'] = pd.to_datetime(states_mar21_df.loc[:, 'date'])

#counties20to23_df['month'] = counties20to23_df['date'].dt.month
states_mar21_df= states_mar_df[states_mar_df['date'].dt.year == 2021]
#save df as a csv file
states_mar21_df.to_csv('data/states_mar21.csv')
#show df
states_mar21_df
# Out:
#             date          state  fips    cases  deaths
# 19979 2021-03-01        Alabama     1   493769    9931
# 19980 2021-03-01         Alaska     2    58229     289
# 19981 2021-03-01        Arizona     4   818268   15979
# 19982 2021-03-01       Arkansas     5   322509    5250
# 19983 2021-03-01     California     6  3573775   52487
# ...          ...            ...   ...      ...     ...
# 21679 2021-03-31       Virginia    51   618976   10252
# 21680 2021-03-31     Washington    53   366907    5309
# 21681 2021-03-31  West Virginia    54   141738    2676
# 21682 2021-03-31      Wisconsin    55   636250    7316
# 21683 2021-03-31        Wyoming    56    56310     700
#
# [1705 rows x 5 columns]

# %%
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
#datetime.datetime(2014, 7, 28, 18, 54, 55, 99000)
#states_mar_df['date'] = pd.to_datetime(states_mar_df['date'])

states_mar22_df.loc[:, 'date'] = pd.to_datetime(states_mar22_df.loc[:, 'date'])

#counties20to23_df['month'] = counties20to23_df['date'].dt.month
states_mar22_df= states_mar_df[states_mar_df['date'].dt.year == 2022]
#save df as a csv file
states_mar22_df.to_csv('data/states_mar22.csv')
#show df
states_mar22_df
# Out:
#             date           state  fips    cases  deaths
# 40214 2022-03-01         Alabama     1  1280351   18287
# 40215 2022-03-01          Alaska     2   237977    1128
# 40216 2022-03-01  American Samoa    60       94       0
# 40217 2022-03-01         Arizona     4  1976890   27946
# 40218 2022-03-01        Arkansas     5   820677   10579
# ...          ...             ...   ...      ...     ...
# 41945 2022-03-31        Virginia    51  1668891   19692
# 41946 2022-03-31      Washington    53  1455632   12540
# 41947 2022-03-31   West Virginia    54   497769    6831
# 41948 2022-03-31       Wisconsin    55  1585495   14302
# 41949 2022-03-31         Wyoming    56   156112    1791
#
# [1736 rows x 5 columns]

# %%
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')

#datetime.datetime(2014, 7, 28, 18, 54, 55, 99000)
#states_mar_df['date'] = pd.to_datetime(states_mar_df['date'])

states_mar23_df.loc[:, 'date'] = pd.to_datetime(states_mar23_df.loc[:, 'date'])

states_mar23_df= states_mar_df[states_mar_df['date'].dt.year == 2023]

#save df as a csv file
states_mar23_df.to_csv('data/states_mar23.csv')

#show df
states_mar23_df
# Out:
#             date           state  fips    cases  deaths
# 60654 2023-03-01         Alabama     1  1642062   21511
# 60655 2023-03-01          Alaska     2   307377    1438
# 60656 2023-03-01  American Samoa    60     8320      34
# 60657 2023-03-01         Arizona     4  2440294   33077
# 60658 2023-03-01        Arkansas     5  1004752   12984
# ...          ...             ...   ...      ...     ...
# 61937 2023-03-23        Virginia    51  2298300   23782
# 61938 2023-03-23      Washington    53  1940704   15905
# 61939 2023-03-23   West Virginia    54   645710    8132
# 61940 2023-03-23       Wisconsin    55  2014524   16485
# 61941 2023-03-23         Wyoming    56   185800    2014
#
# [1288 rows x 5 columns]

# %%
#Pull columns needed (date, county,state,cases,and deaths) from dataframes 
# Merge state dataframes for March 2020-2023

statesmar20to21_df = pd.merge(states_mar20_df, states_mar21_df, on=['date','state','fips','cases','deaths'], how='outer')
statesmar22to23_df = pd.merge(states_mar22_df, states_mar23_df, on=['date','state','fips','cases','deaths'], how='outer')
statesmar20to23_df = pd.merge(statesmar20to21_df, statesmar22to23_df,  on=['date','state','fips','cases','deaths'], how='outer')



print(statesmar20to23_df)
# Out:
#            date          state  fips    cases  deaths
# 0    2020-03-01        Arizona     4        1       0
# 1    2020-03-01     California     6       33       0
# 2    2020-03-01        Florida    12        2       0
# 3    2020-03-01       Illinois    17        3       0
# 4    2020-03-01  Massachusetts    25        1       0
# ...         ...            ...   ...      ...     ...
# 6093 2023-03-23       Virginia    51  2298300   23782
# 6094 2023-03-23     Washington    53  1940704   15905
# 6095 2023-03-23  West Virginia    54   645710    8132
# 6096 2023-03-23      Wisconsin    55  2014524   16485
# 6097 2023-03-23        Wyoming    56   185800    2014
#
# [6098 rows x 5 columns]

# %%
#Create a lineplot for March 2020 to March 2023
# Applying filter function.  

options = ['Colorado', 'New York','Florida'] 
   
# Selecting rows based on condition 
statesmar20to23_df= statesmar20to23_df.loc[statesmar20to23_df['state'].isin(options)]

# %%
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
statesmar20to23_df['date'] = pd.to_datetime(statesmar20to23_df['date'])
# Filter just by the year 2020
statesmar20to23_df['year'] = statesmar20to23_df['date'].dt.year
statesmar20to23_df['date'] = pd.to_datetime(statesmar20to23_df['date'])

#Create datafrmae
statesmar_year20_df= statesmar20to23_df[statesmar20to23_df['date'].dt.year == 2020]

#Drop the date column
statesmar_year20_df.drop('date', axis=1, inplace=True)


#Disply dataframe
statesmar_year20_df
# Out:
# C:\Users\lesli\AppData\Local\Temp\ipykernel_26912\2662669943.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   statesmar_year20_df.drop('date', axis=1, inplace=True)
#          state  fips  cases  deaths  year
# 2      Florida    12      2       0  2020
# 6     New York    36      1       0  2020
# 15     Florida    12      2       0  2020
# 21    New York    36      1       0  2020
# 30     Florida    12      3       0  2020
# ...        ...   ...    ...     ...   ...
# 1268   Florida    12   5695      72  2020
# 1292  New York    36  67504    1512  2020
# 1319  Colorado     8   2990      69  2020
# 1323   Florida    12   6742      85  2020
# 1347  New York    36  76211    1929  2020
#
# [89 rows x 5 columns]

# %%
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
statesmar20to23_df['date'] = pd.to_datetime(statesmar20to23_df['date'])
# Filter just by the year 2021
statesmar20to23_df['year'] = statesmar20to23_df['date'].dt.year
statesmar20to23_df['date'] = pd.to_datetime(statesmar20to23_df['date'])

#Create datafrmae
statesmar_year21_df= statesmar20to23_df[statesmar20to23_df['date'].dt.year == 2021]

#Drop the date column
statesmar_year21_df.drop('date', axis=1, inplace=True)

#Disply dataframe
statesmar_year21_df
# Out:
# C:\Users\lesli\AppData\Local\Temp\ipykernel_26912\3070363520.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   statesmar_year21_df.drop('date', axis=1, inplace=True)
#          state  fips    cases  deaths  year
# 1374  Colorado     8   432186    6046  2021
# 1378   Florida    12  1910913   30998  2021
# 1402  New York    36  1650560   47247  2021
# 1429  Colorado     8   432939    6054  2021
# 1433   Florida    12  1918092   31134  2021
# ...        ...   ...      ...     ...   ...
# 2973   Florida    12  2052433   33337  2021
# 2997  New York    36  1863912   49696  2021
# 3024  Colorado     8   464782    6175  2021
# 3028   Florida    12  2057727   33424  2021
# 3052  New York    36  1871595   49790  2021
#
# [93 rows x 5 columns]

# %%
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
statesmar20to23_df['date'] = pd.to_datetime(statesmar20to23_df['date'])
# Filter just by the year 2022
statesmar20to23_df['year'] = statesmar20to23_df['date'].dt.year
statesmar20to23_df['date'] = pd.to_datetime(statesmar20to23_df['date'])

#Create datafrmae
statesmar_year22_df= statesmar20to23_df[statesmar20to23_df['date'].dt.year == 2022]

#Drop the date column
statesmar_year22_df.drop('date', axis=1, inplace=True)

#Disply dataframe
statesmar_year22_df
# Out:
# C:\Users\lesli\AppData\Local\Temp\ipykernel_26912\633742939.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   statesmar_year22_df.drop('date', axis=1, inplace=True)
#          state  fips    cases  deaths  year
# 3080  Colorado     8  1320858   12028  2022
# 3084   Florida    12  5808620   70247  2022
# 3108  New York    36  4909771   66791  2022
# 3136  Colorado     8  1321703   12035  2022
# 3140   Florida    12  5810369   70247  2022
# ...        ...   ...      ...     ...   ...
# 4708   Florida    12  5847587   73138  2022
# 4732  New York    36  4973964   67306  2022
# 4760  Colorado     8  1351404   12174  2022
# 4764   Florida    12  5849949   73244  2022
# 4788  New York    36  4978875   67313  2022
#
# [93 rows x 5 columns]

# %%
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')
statesmar20to23_df['date'] = pd.to_datetime(statesmar20to23_df['date'])
# Filter just by the year 2023
statesmar20to23_df['year'] = statesmar20to23_df['date'].dt.year
statesmar20to23_df['date'] = pd.to_datetime(statesmar20to23_df['date'])

#Create datafrmae
statesmar_year23_df= statesmar20to23_df[statesmar20to23_df['date'].dt.year == 2023]

statesmar_year23_df.drop('date', axis=1, inplace=True)


#Disply dataframe
statesmar_year23_df
# Out:
# C:\Users\lesli\AppData\Local\Temp\ipykernel_26912\4095167319.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   statesmar_year23_df.drop('date', axis=1, inplace=True)
#          state  fips    cases  deaths  year
# 4816  Colorado     8  1762392   14127  2023
# 4820   Florida    12  7473371   86294  2023
# 4844  New York    36  6777357   79643  2023
# 4872  Colorado     8  1762822   14127  2023
# 4876   Florida    12  7473371   86294  2023
# ...        ...   ...      ...     ...   ...
# 5996   Florida    12  7542869   87141  2023
# 6020  New York    36  6803974   80138  2023
# 6048  Colorado     8  1771010   14245  2023
# 6052   Florida    12  7542869   87141  2023
# 6076  New York    36  6805271   80109  2023
#
# [69 rows x 5 columns]

# %%
#Pull columns needed (year, state,cases,and deaths) from dataframes 

# Merge  dataframes
statesmar_year20to21_df = pd.merge(statesmar_year20_df, statesmar_year21_df, on=['year','state','fips','cases','deaths'], how='outer')
statesmar_year20to22_df = pd.merge(statesmar_year20to21_df, statesmar_year22_df, on=['year','state','fips','cases','deaths'], how='outer')

statesmar_year20to23_df = pd.merge(statesmar_year20to22_df, statesmar_year23_df,  on=['year','state','fips','cases','deaths'], how='outer')


print(statesmar_year20to23_df)
# Out:
#         state  fips    cases  deaths  year
# 0    Colorado     8        2       0  2020
# 1    Colorado     8        8       0  2020
# 2    Colorado     8        8       0  2020
# 3    Colorado     8        8       0  2020
# 4    Colorado     8       12       0  2020
# ..        ...   ...      ...     ...   ...
# 339  New York    36  6800591   79982  2023
# 340  New York    36  6801319   79984  2023
# 341  New York    36  6802990   79987  2023
# 342  New York    36  6803974   80138  2023
# 343  New York    36  6805271   80109  2023
#
# [344 rows x 5 columns]

# %%
# Define the colors for each state
color_palette = {"Colorado": "blue", "New York": "red", "Florida": "green"}

#Create a lineplot showing Colorado, New York, and Florida covid cases in March 2020-2023.
covidcasesstates_20to23 = sns.lineplot(x="year", y="cases", hue="state", data=statesmar_year20to23_df, palette=color_palette)
covidcasesstates_20to23.set_title('March 2020 to 2023 Covid Cases')
covidcasesstates_20to23.set_xlabel('Year', fontdict={'size': 15})
covidcasesstates_20to23.set_ylabel('Number of Cases (in millions)', fontdict={'size': 15})
plt.ylim([0, 8000000])
#plt.xlim([0,2023])

#  set the ticks first 
plt.xticks([2020, 2021, 2022, 2023])

  
# set the labels 
#ovidcasesstates_20to23.set_xticklabels(['2020', '2021', '2022', '2023'])

# get the figure object
fig = plt.gcf()

plt.show()
plt.draw()

#Save image
fig.savefig('images/March_20t023_cases.png', dpi=100)
# Out:
# c:\Users\lesli\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\lesli\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\lesli\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# df['Date'] = pd.to_datetime(df['Date']) -- if column is not datetime yet
datetime.strptime('07/28/2014 18:54:55.099', '%m/%d/%Y %H:%M:%S.%f')

counties23_df['date'] = pd.to_datetime(counties23_df['date'])
counties23_mar_df= counties23_df[counties23_df['date'].dt.month == 3]

#save df as a csv file
counties23_mar_df.to_csv('data/counties23_mar.csv')

#show df
counties23_mar_df.columns
# Out:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
#delete unwanted columns for choropleth plot
countiesandcases23_mar_df=counties23_mar_df.drop(columns=['date', 'state','deaths'])

#save as a csv
countiesandcases23_mar_df.to_csv('data/countiesandcases23_mar.csv')
countiesandcases23_mar_df.columns
# Out:
# Index(['county', 'fips', 'cases'], dtype='object')

# %%
#Read csv and create dataframe for us_county_latlng.csv
us_county_latlng_df = pd.read_csv("data/us_county_latlng.csv")

#show dataframe
us_county_latlng_df
# Out:
#       fips_code         name        lng        lat
# 0          1059     Franklin -87.843283  34.442381
# 1         13111       Fannin -84.319296  34.864126
# 2         19109      Kossuth -94.206898  43.204140
# 3         40115       Ottawa -94.810589  36.835878
# 4         42115  Susquehanna -75.800905  41.821277
# ...         ...          ...        ...        ...
# 3228      12029        Dixie -83.158705  29.608068
# 3229      18017         Cass -86.346207  40.761660
# 3230      26091      Lenawee -84.066412  41.894694
# 3231      72003       Aguada -67.175247  18.360392
# 3232      72013      Arecibo -66.674003  18.406540
#
# [3233 rows x 4 columns]

# %%
#Rename column "name" to "county"
us_county_latlng_df.rename(columns = {'name':'county','fips_code':'fips'}, inplace = True) 
  
# After renaming the columns 
print("\nAfter modifying first column:\n", us_county_latlng_df.columns)
# Out:
# After modifying first column:
#  Index(['fips', 'county', 'lng', 'lat'], dtype='object')

# %%
us_county_latlng_df
# Out:
#        fips       county        lng        lat
# 0      1059     Franklin -87.843283  34.442381
# 1     13111       Fannin -84.319296  34.864126
# 2     19109      Kossuth -94.206898  43.204140
# 3     40115       Ottawa -94.810589  36.835878
# 4     42115  Susquehanna -75.800905  41.821277
# ...     ...          ...        ...        ...
# 3228  12029        Dixie -83.158705  29.608068
# 3229  18017         Cass -86.346207  40.761660
# 3230  26091      Lenawee -84.066412  41.894694
# 3231  72003       Aguada -67.175247  18.360392
# 3232  72013      Arecibo -66.674003  18.406540
#
# [3233 rows x 4 columns]

# %%
# Filter the data for Florida, Colorado, and New York
filtered_data = counties23_mar_df[counties23_mar_df["state"].isin(["Florida", "Colorado", "New York"])]

# Get the FIPS codes for the filtered data
fips_codes = filtered_data["fips"].tolist()

# Print the filtered FIPS codes
print(fips_codes)
# Out:
# [8001.0, 8003.0, 8005.0, 8007.0, 8009.0, 8011.0, 8013.0, 8014.0, 8015.0, 8017.0, 8019.0, 8021.0, 8023.0, 8025.0, 8027.0, 8029.0, 8031.0, 8033.0, 8035.0, 8037.0, 8041.0, 8039.0, 8043.0, 8045.0, 8047.0, 8049.0, 8051.0, 8053.0, 8055.0, 8057.0, 8059.0, 8061.0, 8063.0, 8067.0, 8065.0, 8069.0, 8071.0, 8073.0, 8075.0, 8077.0, 8079.0, 8081.0, 8083.0, 8085.0, 8087.0, 8089.0, 8091.0, 8093.0, 8095.0, 8097.0, 8099.0, 8101.0, 8103.0, 8105.0, 8107.0, 8109.0, 8111.0, 8113.0, 8115.0, 8117.0, 8119.0, nan, 8121.0, 8123.0, 8125.0, 12001.0, 12003.0, 12005.0, 12007.0, 12009.0, 12011.0, 12013.0, 12015.0, 12017.0, 12019.0, 12021.0, 12023.0, 12027.0, 12029.0, 12031.0, 12033.0, 12035.0, 12037.0, 12039.0, 12041.0, 12043.0, 12045.0, 12047.0, 12049.0, 12051.0, 12053.0, 12055.0, 12057.0, 12059.0, 12061.0, 12063.0, 12065.0, 12067.0, 12069.0, 12071.0, 12073.0, 12075.0, 12077.0, 12079.0, 12081.0, 12083.0, 12085.0, 12086.0, 12087.0, 12089.0, 12091.0, 12093.0, 12095.0, 12097.0, 12099.0, 12101.0, 12103.0, 12105.0, 121
# ...

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('data/states_mar23.csv')

# Convert the date column to datetime data type
df['date'] = pd.to_datetime(df['date'])

# Group the data by state and find the maximum date and number of cases for each state
last_date_per_state = df.groupby('state').agg({'date': 'max', 'cases': 'last'})

# Print the last date and number of cases for each state
for state, row in last_date_per_state.iterrows():
    last_date = row['date']
    num_cases = row['cases']
    print(f"State: {state}, Last Date: {last_date}, Number of Cases: {num_cases}")
    
# Save the results to a CSV file
last_date_per_state.to_csv('data/last_date_per_state.csv')
# Out:
# State: Alabama, Last Date: 2023-03-23 00:00:00, Number of Cases: 1648385
# State: Alaska, Last Date: 2023-03-23 00:00:00, Number of Cases: 308893
# State: American Samoa, Last Date: 2023-03-23 00:00:00, Number of Cases: 8321
# State: Arizona, Last Date: 2023-03-23 00:00:00, Number of Cases: 2451062
# State: Arkansas, Last Date: 2023-03-23 00:00:00, Number of Cases: 1008303
# State: California, Last Date: 2023-03-23 00:00:00, Number of Cases: 12169158
# State: Colorado, Last Date: 2023-03-23 00:00:00, Number of Cases: 1771010
# State: Connecticut, Last Date: 2023-03-23 00:00:00, Number of Cases: 978456
# State: Delaware, Last Date: 2023-03-23 00:00:00, Number of Cases: 332861
# State: District of Columbia, Last Date: 2023-03-23 00:00:00, Number of Cases: 178226
# State: Florida, Last Date: 2023-03-23 00:00:00, Number of Cases: 7542869
# State: Georgia, Last Date: 2023-03-23 00:00:00, Number of Cases: 2984923
# State: Guam, Last Date: 2023-03-23 00:00:00, Number of Cases: 62077
# ...
